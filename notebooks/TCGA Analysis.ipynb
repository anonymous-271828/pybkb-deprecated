# %%
import os
import compress_pickle
import ipywidgets as widgets
import networkx as nx
import matplotlib.pyplot as plt

from pybkb.bkb import BKB
from pybkb.utils.analysis import make_rv_level_nx
from pybkb.utils.cytoscape import render, render_nx

# %% [markdown]
# ## TCGA Breast Cancer Analysis
# First we will load the learned TCGA BRCA bkb found in the bkb results hosted on Zenodo [here](https://zenodo.org/record/6577348#.Yp3kr-xBxPY). You will need to download these results and then specify your local file path below to load the bkb. The bkb will be found at: /path/to/results/bkb/tcga/tcga-brca.bkb

# %%
# Load TCGA BKB
bkb = BKB.load('path/to/results/bkb/tcga/tcga-brca.bkb') # <- Change me!

# %% [markdown]
# Here are all the features used to learn the BKB.

# %%
for n in list(bkb.non_source_features):
    if "" in n:
        print(n)
# Out:
# AHNAK
# C10orf12
# RP11-407N17.3
# ERBB2-chr17:39723967
# ADGRG4
# TP53-chr17:7675095
# TP53-chr17:7674220
# ANK3
# GOLGB1
# TNN
# TP53-chr17:7674250
# VPS13D
# LYST
# NEB
# PIK3CA-chr3:179218304
# CIT
# MYLK
# CSMD3
# NCOR1
# PIK3CA-chr3:179218306
# RAPGEF6
# TP53-chr17:7674947
# PKHD1
# RYR3
# MUC4
# SETD2
# MFAP5-chr12:8650521
# CNTNAP5
# KDM5B
# FLG2
# HUWE1
# COL12A1
# VPS13C
# ITPR2
# MKI67
# FMN2
# IGSF10
# MUC17
# THSD7B
# ANKRD17
# SPTA1
# RBMXL3
# CUBN
# ZFPM2
# PIK3CA-chr3:179234297
# DLC1
# SCN2A
# GATA3-chr10:8064095
# PIK3CA-chr3:179234169
# HIST1H3B-chr6:26031841
# COL4A5
# ADCY9
# TENM1
# DOCK11
# PCDHB12
# MYH7
# TP53-chr17:7670685
# PTPRF
# LAMA4
# YLPM1
# PIK3CA-chr3:179234286
# GRIN2B
# TP53BP1
# COL6A5
# AFF2
# SPATA31D5P
# CREBBP
# TP53-chr17:7674872
# TP53-chr17:7675085
# SETX
# LRP1B
# PLCH1
# TEP1
# CHD6
# FAT3
# MXRA5
# DCC
# LCT
# MUC4-chr3:195783009
# SACS
# F8
# KCNT2
# CACNA1D
# F5
# PIK3CA
# SPTAN1
# SPTBN2
# RIMS1
# AK9
# PCLO
# COL7A1
# CCDC168
# ANKRD11
# ANKRD36
# SGSM1
# FBXW7-chr4:152350097
# ALDOA-chr16:30065810
# COL14A1
# RIF1
# KIAA0430
# IRS4
# TG
# COL4A6
# FOXA1-chr14:37592256
# ERBB3
# MGAM
# TP53-chr17:7673803
# TP53
# SLIT2
# TP53-chr17:7674953
# DYNC1H1
# CEP192
# TDRD6
# SETDB1
# CACNA1C
# AKAP6
# SMG1
# DMD
# TP53-chr17:7673767
# SCN11A
# WDR17
# BRCA2
# DST
# SPATA31D1
# TP53-chr17:7674292
# CD9-chr12:6235559
# FGFR2-chr10:121498520
# PIK3CA-chr3:179203765
# KMT2E
# RAD54B
# WDR87
# CEP350
# FCRL5
# UNC79
# RUNX1
# RYR2
# ATM
# TRIM50-chr7:73325571
# SYNE1
# NRXN2
# ZNF208
# PCDH11X
# CENPE
# SCN1A
# XIRP2
# ANK1
# HERC2
# HTATSF1
# APC
# USH2A
# FOXA1-chr14:37592107
# TCHH
# MACF1
# WDFY4
# TANC2
# NALCN
# SELP
# GTF2IRD2-chr7:74822357
# ABCA9
# ABCC9
# TAF1L
# CAMSAP2
# HECW1
# MYH10
# HEG1
# CD163L1
# PLXNA2
# DNAH12
# TP53-chr17:7675088
# DNAH17
# CHD9
# CHD7
# REXO1L1P
# ABCA12
# MUC16
# DNAH6
# UBR5
# TRRAP
# MED12
# PLCE1
# MRC1
# TEX15
# HDLBP
# RANBP2
# TLR4
# C2orf16
# TOPBP1
# TP53-chr17:7675076
# TP53-chr17:7673776
# SF3B1-chr2:197402110
# TTN
# ARFGEF1
# ITPR3
# ASTN1
# PDZD2
# KIAA1549L
# TSHZ3
# FBXW7
# RP1
# CADPS
# CMYA5
# FAM186A
# MYO18B
# PIK3CA-chr3:179210291
# ASPM
# ADCY8
# USP34
# SVIL
# ADAMTSL3
# WSCD2
# EML5
# TP53-chr17:7673802
# RYR1
# CDH1-chr16:68738315
# COL11A1
# PRDM10
# CACNA1E
# ITPR1
# FBN1
# KIF1B
# ADGRV1
# FLG
# MUC2
# PDE4DIP
# SAGE1
# MYT1L
# NF1
# CFH
# MAP3K1
# KRAS-chr12:25245350
# PIK3CA-chr3:179218294
# CCDC180
# FAT1
# CDH1
# FLNA
# ALMS1
# DCHS2
# TP53-chr17:7674894
# DNAH9
# HIST1H3B
# PIK3CA-chr3:179218303
# FOXA1
# OTOF
# FGFR2
# DNAH5
# FREM2
# KMT2C
# DBNL-chr7:44040806
# NUP153
# DENND4B
# DCHS1
# VPS13B
# EYS
# LRBA
# COL5A3-chr19:9997417
# TP53-chr17:7673764
# UBR4
# TRPM6
# CDH23
# CEP290
# AHCTF1
# BRWD3
# ERBB2-chr17:39724747
# ZFHX4
# MYH14
# PCDHGB4-chr5:141389874
# FAM208B
# NCOA6
# ABCA8
# ZP4
# PCNT
# RIMS2
# GOLGA6L10-chr15:82345024
# MGA
# MUC5B
# USP9X
# CACNA1B
# CENPF
# PIK3CA-chr3:179221146
# CEP162
# CFAP47
# NBEAL1
# ATAD2B
# DNAH1
# SHROOM2
# CPS1
# ZNF462
# NID1
# NAV3
# KMT2D
# MYH8
# DNHD1
# KAT6B
# CNTN1
# CSMD2
# DNAH2
# MYCBP2
# NUP160
# TP53-chr17:7674221
# PEG3
# CHD4
# CBFB
# SCN8A
# SCN10A
# TP53-chr17:7674945
# ITIH6
# PTPRD
# FAM47A
# KAT6A
# LRP1
# MYH1
# CSPP1
# HERC1
# DMXL2
# DAB1-chr1:57015131
# HDAC6
# TP53-chr17:7674950
# MUC4-chr3:195783008
# MDN1
# SHANK1
# ATRX
# WDFY3
# TP53-chr17:7673781
# CCNB3
# GRM4-chr6:34022043
# PTEN
# GCC2
# NOTCH2
# KIAA2026
# BRWD1
# PRKDC
# LOXHD1
# PREX2
# QSER1
# SPHKAP
# HRNR
# TENM2
# MADD
# ERBB2
# C5orf42
# DNAH3
# CH17-140K24.8
# RELN
# THSD7A
# BAZ2B
# KIAA1210
# SVEP1
# AKT1-chr14:104780214
# ATP7A
# PCDH19
# CAD
# PIK3CA-chr3:179199690
# PRUNE2
# ATP10A
# MYO10
# TP53-chr17:7674229
# UHRF1BP1L
# MYO7A
# PKD1L1
# TP53-chr17:7673788
# COL22A1
# CSMD1
# SCN7A
# SCN9A
# TAF1
# FREM1
# RYR3-chr15:33662609
# GRID1
# KIAA2022
# SYNE2
# KIAA2018
# SI
# ATP10B
# PRRC2B
# HCFC1
# AMER1
# ZNF536
# TP53-chr17:7673537
# KIF4A
# CDH20
# COL4A4
# TPR
# HYDIN
# KIAA1109
# PIK3CA-chr3:179218307
# HECTD1
# ASXL3
# HTT
# PTEN-chr10:87933148
# PMFBP1
# UNC5D
# MAP2K4
# ANK2
# FRMPD4
# MROH2B
# TNXB
# SF3B1
# KIF1B-chr1:10352639
# ZDBF2
# ARID1B
# ERCC6
# MAP1A
# PKHD1L1
# CDH1-chr16:68810236
# PCDH15
# CACNA1A
# FOXA1-chr14:37592035
# UTP20
# DNAH8
# CEP170
# BIRC6
# PIK3CA-chr3:179210192
# XKR4
# COL6A3
# HECW2
# BRINP3
# RGAG1
# MTOR
# MYH9
# FAT4
# DNAH10
# CKAP5
# GRIA3
# PRRC2C
# PIWIL1
# GPR179
# COL6A6
# SPATA31C1
# LAMA3
# SPAG17
# TMEM67-chr8:93809963
# OTOGL
# CNTLN
# HMCN1
# ADAMTS20
# FLNC
# RNF213
# THADA
# DNAH11
# ADAMTSL1
# WNK3
# PLXNA3
# LRP2
# AKAP9
# IGHG1
# SRCAP
# AKT1
# UNC13C
# LRRIQ1
# SPTB
# KIF13A
# VCAN
# AHNAK2
# MEGF8
# TLN1
# COL4A3
# VPS13A
# MAP2
# MAGI1
# HIVEP1
# CAMSAP1
# TP53-chr17:7674885
# CACNA1F
# ABCA13
# FBN3
# GREB1L
# SSPO
# GRIK2
# MYO5B
# DOCK2
# REV3L
# NINL
# PAPPA2
# CFTR
# DYNC2H1
# TP53-chr17:7675190
# FAM47C
# TNRC6B
# KIF16B
# FRAS1
# UTRN
# RNF4-chr4:2514476
# TBC1D25
# LRRC7
# OBSCN
# DNAH7
# PLEC
# ZAN
# FCGBP
# LAMA1
# GON4L
# APOB
# PLCB4
# MYO16
# FAT2
# SDK1
# PCNXL2
# DNM1P47-chr15:101764200
# LAMA2
# CBLB

# %% [markdown]
# Here we will make a NetworkX object so that we can perform some simple graph analysis.

# %%
G = make_rv_level_nx(bkb, include_sources=False)

# %% [markdown]
# The following render will show a subgraph of the BKB between HER genes and specific TP53 SNPs on the RV level. This is the graph used to create Figure 2(a) in the paper.

# %%
render_nx(G, subgraph_on_partial=['HER', 'TP53-chr'])
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'dagre', 'nodeSpacing': 10, 'edgeLengthVal': 10}, cytoscape_style=[{…

# %% [markdown]
# Here is we see the cyclic random variable relationship between PIK3CA-chr3:179234297 and TP53. This is the graph used to create Figure 2(b) in the paper.

# %%
render(bkb, hide_sources=True, subgraph_on=['PIK3CA-chr3:179234297', 'TP53'], remove_prior_snodes=True)
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'dagre', 'nodeSpacing': 10, 'edgeLengthVal': 10}, cytoscape_style=[{…

# %% [markdown]
# Now we will try to find all such simple random variable cycles in the learned BKB to hypothesize potential driver mutations.

# %%
def find_really_simple_cycles(G):
    cycles = []
    for n1 in G.nodes:
        n1_neighbors = nx.neighbors(G, n1)
        for n2 in n1_neighbors:
            n2_neighbors = nx.neighbors(G, n2)
            if n1 in n2_neighbors:
                cycles.append(tuple(sorted([n1, n2])))
    return list(set(cycles))

# %%
find_really_simple_cycles(G)
# Out:
# [('OBSCN', 'TP53'),
#  ('FREM2', 'KMT2C'),
#  ('MAP3K1', 'PIK3CA-chr3:179234297'),
#  ('MUC4-chr3:195783008', 'MUC4-chr3:195783009'),
#  ('PIK3CA-chr3:179234297', 'TTN'),
#  ('AKT1-chr14:104780214', 'NCOA6'),
#  ('DST', 'ITPR1'),
#  ('CAD', 'PIK3CA-chr3:179234297'),
#  ('FLG', 'TP53'),
#  ('KIAA2026', 'KMT2C'),
#  ('PIK3CA-chr3:179234297', 'TP53'),
#  ('PIK3CA', 'PIK3CA-chr3:179234297')]

# %% [markdown]
# Example graph of these simple cycles.

# %%
render_nx(G, subgraph_on=['PIK3CA-chr3:179234297', 'TP53'])
# Out:
# CytoscapeWidget(cytoscape_layout={'name': 'dagre', 'nodeSpacing': 10, 'edgeLengthVal': 10}, cytoscape_style=[{…
